# %%
import numpy as np

import RBN_flip

K = 4
N= 3
N_agent = 3
N_environment = 4
r = 0.5
mutation_rate = 0.5
threshold = 0
d_r = 0.5
d_mutation = 0.5
num_T = 5
num_processes = 5
maxiter = 10
iteration_for_average = 5
#p = 0.5
iterations_convergence = 5
# Create an instance of the RBN class
network = RBN_flip.RBN(K,N,r)

# %%
network.plot_states()

# %%
RBN_flip.print_pmf(network, N)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19908\122642426.py in <module>
# ----> 1 RBN_flip.print_pmf(network, N)
#
# ~\OneDrive\Bureaublad\Capstone_g\RBN_flip.py in print_pmf(network, N)
#     499     plt.fill_between(X_axis, average1_pmf, alpha=0.2)
#     500     # Setting labels and title for the plot
# --> 501     plt.xlabel('System States (Decimal Value)')
#     502     plt.ylabel('PMF')
#     503     plt.title('Sorted PMF values for 0.1 and 0.1 + dr')
#
# AttributeError: 'RBN' object has no attribute 'bin_to_bin_str'

# %%
RBN_flip.convergence(num_T, N, network,r)

# %%
RBN_flip.pmf_barplot(network, r, num_T, d_r)

# %%
RBN_flip.sorted_pmf_plot(network, r, num_T, d_r)

# %%
RBN_flip.Fisher_plot(d_r, num_T, threshold, num_processes, network)

# %%
RBN_flip.convergence_plots_mutation(K, r, mutation_rate, N_agent, N_environment, d_mutation, maxiter, iteration_for_average, d_r, num_T, threshold, num_processes)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19908\3779707440.py in <module>
# ----> 1 RBN_flip.convergence_plots_mutation(K, r, mutation_rate, N_agent, N_environment, d_mutation, maxiter, iteration_for_average, d_r, num_T, threshold, num_processes)
#
# ~\OneDrive\Bureaublad\Capstone_g\RBN_flip.py in convergence_plots_mutation(K, r, mutation_rate, N_agent, N_environment, d_mutation, maxiter, iteration_for_average, d_r, num_T, threshold, num_processes)
#     772     return change_array, zero_array, iteration_to_zero_array, rate_array, hellinger_distance_stack
#     773 def calculate_decrease_hellinger_distance_r(K, r, mutation_rate, N_agent, N_environment, d_mutation, maxiter, iteration_for_average, d_r, num_T, threshold,num_processes):
# --> 774     change_array = np.zeros(int(1 / d_r))
#     775     zero_array = np.zeros(int(1 / d_r))
#     776     iteration_to_zero_array = np.zeros(int(1 / d_r))
#
# ~\OneDrive\Bureaublad\Capstone_g\RBN_flip.py in calculate_decrease_hellinger_distance_mutation(K, r, mutation_rate, N_agent, N_environment, d_mutation, maxiter, iteration_for_average, d_r, num_T, threshold, num_processes)
#     654
#     655     return average_count, av_it, av_rate_measure, steps_to_zero_array, av_distance
# --> 656
#     657
#     658
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
RBN_flip.convergence_plots_r(K, r, iterations_convergence, mutation_rate, N_agent, N_environment, d_mutation, maxiter, iteration_for_average, d_r, num_T, threshold, num_processes)
# Out:
# C:\Users\emiel\OneDrive\Bureaublad\Capstone_g\RBN_flip.py:228: RuntimeWarning: divide by zero encountered in log
#   log_pmf = np.where(pmf == 0, 0, np.log(pmf))
# C:\Users\emiel\OneDrive\Bureaublad\Capstone_g\RBN_flip.py:229: RuntimeWarning: divide by zero encountered in log
#   log_pmf_prev = np.where(pmf_prev == 0, 0, np.log(pmf_prev))

# %%
K = 4
N_agent = 5
N_environment = 6
r = 0.5
mutation_rate = 0.5
threshold = 0
d_r = 0.5
d_mutation = 0.5
num_T = 5
num_processes = 5
maxiter = 10
iteration_for_average = 5
#p = 0.5
iterations_convergence = 5

change_array, zero_array, iteration_to_zero_array, rate_array, hellinger_distance_stack = RBN_flip.calculate_decrease_hellinger_distance_r(K, r, mutation_rate, N_agent, N_environment, d_mutation, maxiter, iteration_for_average, d_r, num_T, threshold,num_processes)

r_values = np.linspace(0, 1, len(change_array))
RBN_flip.plot_results_r(r_values, rate_array)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19908\1923521988.py in <module>
#      14 iterations_convergence = 5
#      15
# ---> 16 change_array, zero_array, iteration_to_zero_array, rate_array, hellinger_distance_stack = RBN_flip.calculate_decrease_hellinger_distance_r(K, r, mutation_rate, N_agent, N_environment, d_mutation, maxiter, iteration_for_average, d_r, num_T, threshold,num_processes)
#      17
#      18 r_values = np.linspace(0, 1, len(change_array))
#
# ~\OneDrive\Bureaublad\Capstone_g\RBN_flip.py in calculate_decrease_hellinger_distance_r(K, r, mutation_rate, N_agent, N_environment, d_mutation, maxiter, iteration_for_average, d_r, num_T, threshold, num_processes)
#     740
#     741     return change_array, zero_array, iteration_to_zero_array, rate_array, hellinger_distance_stack
# --> 742
#     743
#     744 #This function exists to calculate the hellinger distance for different environments and agents, with the goal of finding
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
change_array, zero_array, iteration_to_zero_array, rate_array, hellinger_distance_stack = RBN_flip.calculate_decrease_hellinger_distance_mutation(K, r, mutation_rate, N_agent, N_environment, d_mutation, maxiter,
                                                   iteration_for_average, d_r, num_T, threshold,
                                                   num_processes)
mutation_values = np.linspace(0, 1, len(change_array))
RBN_flip.plot_results_mutation(mutation_values, rate_array)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19908\3102821717.py in <module>
# ----> 1 change_array, zero_array, iteration_to_zero_array, rate_array, hellinger_distance_stack = RBN_flip.calculate_decrease_hellinger_distance_mutation(K, r, mutation_rate, N_agent, N_environment, d_mutation, maxiter,
#       2                                                    iteration_for_average, d_r, num_T, threshold,
#       3                                                    num_processes)
#       4 mutation_values = np.linspace(0, 1, len(change_array))
#       5 RBN_flip.plot_results_mutation(mutation_values, rate_array)
#
# ~\OneDrive\Bureaublad\Capstone_g\RBN_flip.py in calculate_decrease_hellinger_distance_mutation(K, r, mutation_rate, N_agent, N_environment, d_mutation, maxiter, iteration_for_average, d_r, num_T, threshold, num_processes)
#     654
#     655
# --> 656 def calculate_average_change_multi_initial(K, N_agent, N_environment, r, d_r, num_T,threshold,num_processes, mutation_rate, maxiter, iteration_for_average):
#     657     average_count = 0
#     658     steps_to_zero_array = np.zeros(0)
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
K = 4
N_agent = 5
N_environment = 6
r = 0.5
mutation_rate = 0.5
threshold = 0
d_r = 0.5
d_mutation = 0.5
num_T = 5
num_processes = 5
maxiter = 4
iteration_for_average = 2
#p = 0.5
iterations_convergence = 5

r_and_mutation_stack = RBN_flip.calculate_decrease_Hellinger_per_r_and_mutation_rate(K, r, mutation_rate, N_agent, N_environment, maxiter, iteration_for_average,  d_r, d_mutation, num_T, threshold, num_processes)
RBN_flip.heatmap_r_mutation(r_and_mutation_stack, d_mutation,d_r)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19908\741491630.py in <module>
#      14 iterations_convergence = 5
#      15
# ---> 16 r_and_mutation_stack = RBN_flip.calculate_decrease_Hellinger_per_r_and_mutation_rate(K, r, mutation_rate, N_agent, N_environment, maxiter, iteration_for_average,  d_r, d_mutation, num_T, threshold, num_processes)
#      17 RBN_flip.heatmap_r_mutation(r_and_mutation_stack, d_mutation,d_r)
#
# ~\OneDrive\Bureaublad\Capstone_g\RBN_flip.py in calculate_decrease_Hellinger_per_r_and_mutation_rate(K, r, mutation_rate, N_agent, N_environment, maxiter, iteration_for_average, d_r, d_mutation, num_T, threshold, num_processes)
#     788         change_array[i] = average_count
#     789         av_it /= iteration_for_average
# --> 790         av_rate_measure /= iteration_for_average
#     791         rate_array[i] = av_rate_measure
#     792         av_distance /= iteration_for_average
#
# ~\OneDrive\Bureaublad\Capstone_g\RBN_flip.py in calculate_decrease_hellinger_distance_r(K, r, mutation_rate, N_agent, N_environment, d_mutation, maxiter, iteration_for_average, d_r, num_T, threshold, num_processes)
#     740
#     741     return change_array, zero_array, iteration_to_zero_array, rate_array, hellinger_distance_stack
# --> 742
#     743
#     744 #This function exists to calculate the hellinger distance for different environments and agents, with the goal of finding
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
r = 0.5
mutation_rate = 0.5
threshold = 0
d_r = 0.1
d_mutation = 0.1
num_T = 10
num_processes = 5
maxiter = 100
iteration_for_average = 20
#p = 0.5
iterations_convergence = 20

RBN_flip.convergence_plots_r(K, r, iterations_convergence, mutation_rate, N_agent, N_environment,d_mutation, maxiter, iteration_for_average, d_r, num_T, threshold, num_processes)

# %%
r = 0.5
mutation_rate = 0.5
threshold = 0
d_r = 0.1
d_mutation = 0.1
num_T = 5
num_processes = 5
maxiter = 10
iteration_for_average = 5
#p = 0.5
iterations_convergence = 5

RBN_flip.convergence_plots_mutation(K, r, mutation_rate,N_agent, N_environment, d_mutation, maxiter, iteration_for_average, d_r, num_T, threshold, num_processes)
