# %%
import numpy as np

import RBN_flip


K = 4
N= 8
N_agent = 8
N_environment = 10
r = 0.5
mutation_rate = 0.5
threshold = 0
d_r = 0.05
d_mutation = 0.05
num_T = 30
num_processes = 10
maxiter = 150
iteration_for_average = 30
#p = 0.5
iterations_convergence = 20
# Create an instance of the RBN class
network = RBN_flip.RBN(K,N,r)

# %% [markdown]
# Plotting the graph

# %%
network.plot_states()

# %% [markdown]
# Printing the attractors and their probability

# %%
RBN_flip.print_pmf(network, N)
# Out:
# p( 10111000 ) : 1.0
# Probability sum: 1.0

# %% [markdown]
# # Calculating Fisher Information
#
# The cells below show proof that the Fisher information is calculated appropriately

# %% [markdown]
# Showing that the average of pmfs converges when the number used for the average is higher

# %%
RBN_flip.convergence(num_T, N, network,r)

# %% [markdown]
# A bar plot, showing the probability of each state of the network for r = 0.1 and r = 0.5
# (far and close to the maximum of the Fisher information).
# Now sorted on probability

# %%
RBN_flip.sorted_pmf_plot(network, r, num_T, d_r)

# %% [markdown]
# Calculating the Fisher information for multiple r values
# Also showing the value of the difference between pmfs for a d_r, as a check on whether the code behind the Fisher plot works.

# %%
RBN_flip.Fisher_plot(d_r, num_T, threshold, num_processes, network)
# Out:
# C:\Users\emiel\OneDrive\Bureaublad\Capstone_g\RBN_flip.py:315: RuntimeWarning: divide by zero encountered in log
#   log_pmf = np.where(pmf == 0, 0, np.log(pmf))
# C:\Users\emiel\OneDrive\Bureaublad\Capstone_g\RBN_flip.py:316: RuntimeWarning: divide by zero encountered in log
#   log_pmf_prev = np.where(pmf_prev == 0, 0, np.log(pmf_prev))

# %% [markdown]
# Showing how the Hellinger distance decreases over epochs for a certain mutation rate and different r

# %%
import time

start_time = time.time()

change_array, zero_array, iteration_to_zero_array, rate_array, hellinger_distance_stack = RBN_flip.calculate_decrease_hellinger_distance_r(K, r, iterations_convergence, mutation_rate, N_agent, N_environment, d_mutation, maxiter, iteration_for_average, d_r, num_T, threshold,num_processes)

r_values = np.linspace(0, 1, len(change_array))
RBN_flip.plot_results_r(r_values, rate_array)
end_time = time.time() # End time after the operation

duration = end_time - start_time # Duration of operation

print(f"The operation took {duration} seconds to complete.")
# Out:
# The operation took 2817.904945373535 seconds to complete.

# %% [markdown]
# Showing how the Hellinger distance decreasesover epochs for a certain r and different mutation rates

# %%
start_time = time.time()

change_array, zero_array, iteration_to_zero_array, rate_array, hellinger_distance_stack = RBN_flip.calculate_decrease_hellinger_distance_mutation(K, r, mutation_rate, N_agent, N_environment, d_mutation, maxiter,
                                                   iteration_for_average, d_r, num_T, threshold,
                                                   num_processes)
mutation_values = np.linspace(0, 1, len(change_array))
RBN_flip.plot_results_mutation(mutation_values, rate_array)

end_time = time.time() # End time after the operation

duration = end_time - start_time # Duration of operation

print(f"The operation took {duration} seconds to complete.")
# Out:
# The operation took 2978.6676535606384 seconds to complete.

# %% [markdown]
# Showing how the Hellinger distance decreasesover epochs for a certain mutation values and different r

# %%
K = 4
N= 6
N_agent = 6
N_environment = 8
r = 0.5
mutation_rate = 0.5
threshold = 0
d_r = 0.05
d_mutation = 0.05
num_T = 30
num_processes = 10
maxiter = 150
iteration_for_average = 30
#p = 0.5
iterations_convergence = 20
# Create an instance of the RBN class
network = RBN_flip.RBN(K,N,r)



start_time = time.time()

RBN_flip.convergence_plots_r(K, r, iterations_convergence, mutation_rate, N_agent, N_environment,d_mutation, maxiter, iteration_for_average, d_r, num_T, threshold, num_processes)
end_time = time.time() # End time after the operation

duration = end_time - start_time # Duration of operation

print(f"The operation took {duration} seconds to complete.")
# Out:
# The operation took 1131.0177693367004 seconds to complete.

# %% [markdown]
# Showing how the Hellinger distance decreasesover epochs for a certain r and different mutation rates

# %%
start_time = time.time()
RBN_flip.convergence_plots_mutation(K, r, mutation_rate,N_agent, N_environment, d_mutation, maxiter, iteration_for_average, d_r, num_T, threshold, num_processes)
end_time = time.time() # End time after the operation

duration = end_time - start_time # Duration of operation

print(f"The operation took {duration} seconds to complete.")
# Out:
# The operation took 974.3187348842621 seconds to complete.

# %% [markdown]
# Showing how the Hellinger distance decreases over epochs for a certain mutation rate and different r

# %%
K = 4  #Connectivity
N = 6
N_agent = 6  # Number of nodes agent
N_environment = 8  # Number of nodes environment
r = 0.5  # the value of the flip probability
mutation_rate = 0.5  # the value of the mutation rate
threshold = 0  # threshold for when we say the Hellinger distance between an agent and a Environment is negligible
d_r = 0.1  # values of the change of r, used for analysis
d_mutation = 0.1  # values of the change of the mutation rate, used for analysis
num_T = 20  # the humber of pmfs that is used to create a pmf that is used to calculate the Fisher information
maxiter = 150  # maximum number of iterations in the mutation process
iteration_for_average = 30  #amount of iterations of initializations of agents and environments that is used for analysis.
iterations_convergence = 10  # Not used at the moment
num_processes = 10  # Not used at the moment
network = RBN_flip.RBN(K,N,r)


start_time = time.time()

r_and_mutation_stack = RBN_flip.calculate_decrease_Hellinger_per_r_and_mutation_rate(K, r,iterations_convergence, mutation_rate, N_agent,
                                                                                         N_environment, maxiter,
                                                                                         iteration_for_average, d_r,
                                                                                         d_mutation, num_T, threshold,
                                                                                         num_processes)
RBN_flip.heatmap_r_mutation(r_and_mutation_stack, d_mutation, d_r)

end_time = time.time() # End time after the operation

duration = end_time - start_time # Duration of operation

print(f"The operation took {duration} seconds to complete.")
# Out:
# [[ 0.00000000e+00]
#  [-3.37241542e-03]
#  [-1.74811137e-03]
#  [-1.36576900e-03]
#  [-4.11259802e-05]
#  [-3.12437188e-04]
#  [-1.08058450e-03]
#  [-1.34445358e-03]
#  [-2.67738618e-03]
#  [-3.74065663e-03]]
# [[ 0.00000000e+00  0.00000000e+00]
#  [-3.37241542e-03 -2.85911676e-03]
#  [-1.74811137e-03 -2.87533038e-03]
#  [-1.36576900e-03 -8.50623954e-04]
#  [-4.11259802e-05 -5.90799936e-04]
#  [-3.12437188e-04 -1.78756084e-04]
#  [-1.08058450e-03 -8.61012011e-04]
#  [-1.34445358e-03 -1.63821470e-03]
#  [-2.67738618e-03 -1.68047951e-03]
#  [-3.74065663e-03 -2.88888889e-03]]
# [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [-3.37241542e-03 -2.85911676e-03 -3.41272051e-03]
#  [-1.74811137e-03 -2.87533038e-03 -2.00436752e-03]
#  [-1.36576900e-03 -8.50623954e-04 -1.40337605e-03]
#  [-4.11259802e-05 -5.90799936e-04 -5.68893105e-04]
#  [-3.12437188e-04 -1.78756084e-04 -7.79828304e-05]
#  [-1.08058450e-03 -8.61012011e-04 -4.27957960e-04]
#  [-1.34445358e-03 -1.63821470e-03 -1.11398056e-03]
#  [-2.67738618e-03 -1.68047951e-03 -2.27790146e-03]
#  [-3.74065663e-03 -2.88888889e-03 -3.56445771e-03]]
# [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [-3.37241542e-03 -2.85911676e-03 -3.41272051e-03 -4.37935706e-03]
#  [-1.74811137e-03 -2.87533038e-03 -2.00436752e-03 -4.09839552e-03]
#  [-1.36576900e-03 -8.50623954e-04 -1.40337605e-03 -1.11152028e-03]
#  [-4.11259802e-05 -5.90799936e-04 -5.68893105e-04 -7.24705834e-04]
#  [-3.12437188e-04 -1.78756084e-04 -7.79828304e-05 -7.17330035e-04]
#  [-1.08058450e-03 -8.61012011e-04 -4.27957960e-04 -1.17636850e-03]
#  [-1.34445358e-03 -1.63821470e-03 -1.11398056e-03 -1.11733279e-03]
#  [-2.67738618e-03 -1.68047951e-03 -2.27790146e-03 -2.26954766e-03]
#  [-3.74065663e-03 -2.88888889e-03 -3.56445771e-03 -3.55555556e-03]]
# [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]
#  [-3.37241542e-03 -2.85911676e-03 -3.41272051e-03 -4.37935706e-03
#   -2.57817851e-03]
#  [-1.74811137e-03 -2.87533038e-03 -2.00436752e-03 -4.09839552e-03
#   -2.09486398e-03]
#  [-1.36576900e-03 -8.50623954e-04 -1.40337605e-03 -1.11152028e-03
#   -7.39684185e-04]
#  [-4.11259802e-05 -5.90799936e-04 -5.68893105e-04 -7.24705834e-04
#   -1.02642676e-03]
#  [-3.12437188e-04 -1.78756084e-04 -7.79828304e-05 -7.17330035e-04
#   -4.31280216e-04]
#  [-1.08058450e-03 -8.61012011e-04 -4.27957960e-04 -1.17636850e-03
#   -5.79989635e-04]
#  [-1.34445358e-03 -1.63821470e-03 -1.11398056e-03 -1.11733279e-03
#   -1.30158888e-03]
#  [-2.67738618e-03 -1.68047951e-03 -2.27790146e-03 -2.26954766e-03
#   -2.88680195e-03]
#  [-3.74065663e-03 -2.88888889e-03 -3.56445771e-03 -3.55555556e-03
#   -3.86371729e-03]]
# [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00]
#  [-3.37241542e-03 -2.85911676e-03 -3.41272051e-03 -4.37935706e-03
#   -2.57817851e-03 -2.06755979e-03]
#  [-1.74811137e-03 -2.87533038e-03 -2.00436752e-03 -4.09839552e-03
#   -2.09486398e-03 -2.87661230e-03]
#  [-1.36576900e-03 -8.50623954e-04 -1.40337605e-03 -1.11152028e-03
#   -7.39684185e-04 -1.55581327e-03]
#  [-4.11259802e-05 -5.90799936e-04 -5.68893105e-04 -7.24705834e-04
#   -1.02642676e-03 -4.96670231e-04]
#  [-3.12437188e-04 -1.78756084e-04 -7.79828304e-05 -7.17330035e-04
#   -4.31280216e-04 -6.29011570e-04]
#  [-1.08058450e-03 -8.61012011e-04 -4.27957960e-04 -1.17636850e-03
#   -5.79989635e-04 -9.31851950e-04]
#  [-1.34445358e-03 -1.63821470e-03 -1.11398056e-03 -1.11733279e-03
#   -1.30158888e-03 -1.56152442e-03]
#  [-2.67738618e-03 -1.68047951e-03 -2.27790146e-03 -2.26954766e-03
#   -2.88680195e-03 -2.16546481e-03]
#  [-3.74065663e-03 -2.88888889e-03 -3.56445771e-03 -3.55555556e-03
#   -3.86371729e-03 -3.80035667e-03]]
# [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [-3.37241542e-03 -2.85911676e-03 -3.41272051e-03 -4.37935706e-03
#   -2.57817851e-03 -2.06755979e-03 -3.38488737e-03]
#  [-1.74811137e-03 -2.87533038e-03 -2.00436752e-03 -4.09839552e-03
#   -2.09486398e-03 -2.87661230e-03 -2.21441696e-03]
#  [-1.36576900e-03 -8.50623954e-04 -1.40337605e-03 -1.11152028e-03
#   -7.39684185e-04 -1.55581327e-03 -1.29622652e-03]
#  [-4.11259802e-05 -5.90799936e-04 -5.68893105e-04 -7.24705834e-04
#   -1.02642676e-03 -4.96670231e-04 -5.27534535e-04]
#  [-3.12437188e-04 -1.78756084e-04 -7.79828304e-05 -7.17330035e-04
#   -4.31280216e-04 -6.29011570e-04 -1.16201711e-03]
#  [-1.08058450e-03 -8.61012011e-04 -4.27957960e-04 -1.17636850e-03
#   -5.79989635e-04 -9.31851950e-04 -5.31032429e-04]
#  [-1.34445358e-03 -1.63821470e-03 -1.11398056e-03 -1.11733279e-03
#   -1.30158888e-03 -1.56152442e-03 -8.60700863e-04]
#  [-2.67738618e-03 -1.68047951e-03 -2.27790146e-03 -2.26954766e-03
#   -2.88680195e-03 -2.16546481e-03 -2.28900625e-03]
#  [-3.74065663e-03 -2.88888889e-03 -3.56445771e-03 -3.55555556e-03
#   -3.86371729e-03 -3.80035667e-03 -1.49243351e-03]]
# [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [-3.37241542e-03 -2.85911676e-03 -3.41272051e-03 -4.37935706e-03
#   -2.57817851e-03 -2.06755979e-03 -3.38488737e-03 -4.16314804e-03]
#  [-1.74811137e-03 -2.87533038e-03 -2.00436752e-03 -4.09839552e-03
#   -2.09486398e-03 -2.87661230e-03 -2.21441696e-03 -2.38394249e-03]
#  [-1.36576900e-03 -8.50623954e-04 -1.40337605e-03 -1.11152028e-03
#   -7.39684185e-04 -1.55581327e-03 -1.29622652e-03 -1.57727247e-03]
#  [-4.11259802e-05 -5.90799936e-04 -5.68893105e-04 -7.24705834e-04
#   -1.02642676e-03 -4.96670231e-04 -5.27534535e-04 -8.94795289e-04]
#  [-3.12437188e-04 -1.78756084e-04 -7.79828304e-05 -7.17330035e-04
#   -4.31280216e-04 -6.29011570e-04 -1.16201711e-03 -2.76600893e-04]
#  [-1.08058450e-03 -8.61012011e-04 -4.27957960e-04 -1.17636850e-03
#   -5.79989635e-04 -9.31851950e-04 -5.31032429e-04 -1.48915920e-04]
#  [-1.34445358e-03 -1.63821470e-03 -1.11398056e-03 -1.11733279e-03
#   -1.30158888e-03 -1.56152442e-03 -8.60700863e-04 -1.97606936e-03]
#  [-2.67738618e-03 -1.68047951e-03 -2.27790146e-03 -2.26954766e-03
#   -2.88680195e-03 -2.16546481e-03 -2.28900625e-03 -1.43083744e-03]
#  [-3.74065663e-03 -2.88888889e-03 -3.56445771e-03 -3.55555556e-03
#   -3.86371729e-03 -3.80035667e-03 -1.49243351e-03 -3.15142625e-03]]
# [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]
#  [-3.37241542e-03 -2.85911676e-03 -3.41272051e-03 -4.37935706e-03
#   -2.57817851e-03 -2.06755979e-03 -3.38488737e-03 -4.16314804e-03
#   -3.51200423e-03]
#  [-1.74811137e-03 -2.87533038e-03 -2.00436752e-03 -4.09839552e-03
#   -2.09486398e-03 -2.87661230e-03 -2.21441696e-03 -2.38394249e-03
#   -1.41516789e-03]
#  [-1.36576900e-03 -8.50623954e-04 -1.40337605e-03 -1.11152028e-03
#   -7.39684185e-04 -1.55581327e-03 -1.29622652e-03 -1.57727247e-03
#   -2.07296567e-03]
#  [-4.11259802e-05 -5.90799936e-04 -5.68893105e-04 -7.24705834e-04
#   -1.02642676e-03 -4.96670231e-04 -5.27534535e-04 -8.94795289e-04
#   -1.59009370e-03]
#  [-3.12437188e-04 -1.78756084e-04 -7.79828304e-05 -7.17330035e-04
#   -4.31280216e-04 -6.29011570e-04 -1.16201711e-03 -2.76600893e-04
#   -4.36529051e-04]
#  [-1.08058450e-03 -8.61012011e-04 -4.27957960e-04 -1.17636850e-03
#   -5.79989635e-04 -9.31851950e-04 -5.31032429e-04 -1.48915920e-04
#   -6.08795997e-04]
#  [-1.34445358e-03 -1.63821470e-03 -1.11398056e-03 -1.11733279e-03
#   -1.30158888e-03 -1.56152442e-03 -8.60700863e-04 -1.97606936e-03
#   -1.61999785e-03]
#  [-2.67738618e-03 -1.68047951e-03 -2.27790146e-03 -2.26954766e-03
#   -2.88680195e-03 -2.16546481e-03 -2.28900625e-03 -1.43083744e-03
#   -2.62624356e-03]
#  [-3.74065663e-03 -2.88888889e-03 -3.56445771e-03 -3.55555556e-03
#   -3.86371729e-03 -3.80035667e-03 -1.49243351e-03 -3.15142625e-03
#   -3.43827455e-03]]
# [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00]
#  [-3.37241542e-03 -2.85911676e-03 -3.41272051e-03 -4.37935706e-03
#   -2.57817851e-03 -2.06755979e-03 -3.38488737e-03 -4.16314804e-03
#   -3.51200423e-03 -3.27844124e-03]
#  [-1.74811137e-03 -2.87533038e-03 -2.00436752e-03 -4.09839552e-03
#   -2.09486398e-03 -2.87661230e-03 -2.21441696e-03 -2.38394249e-03
#   -1.41516789e-03 -2.62919705e-03]
#  [-1.36576900e-03 -8.50623954e-04 -1.40337605e-03 -1.11152028e-03
#   -7.39684185e-04 -1.55581327e-03 -1.29622652e-03 -1.57727247e-03
#   -2.07296567e-03 -1.59642805e-03]
#  [-4.11259802e-05 -5.90799936e-04 -5.68893105e-04 -7.24705834e-04
#   -1.02642676e-03 -4.96670231e-04 -5.27534535e-04 -8.94795289e-04
#   -1.59009370e-03 -8.94136407e-04]
#  [-3.12437188e-04 -1.78756084e-04 -7.79828304e-05 -7.17330035e-04
#   -4.31280216e-04 -6.29011570e-04 -1.16201711e-03 -2.76600893e-04
#   -4.36529051e-04 -5.74612768e-04]
#  [-1.08058450e-03 -8.61012011e-04 -4.27957960e-04 -1.17636850e-03
#   -5.79989635e-04 -9.31851950e-04 -5.31032429e-04 -1.48915920e-04
#   -6.08795997e-04 -2.90483080e-04]
#  [-1.34445358e-03 -1.63821470e-03 -1.11398056e-03 -1.11733279e-03
#   -1.30158888e-03 -1.56152442e-03 -8.60700863e-04 -1.97606936e-03
#   -1.61999785e-03 -1.11841911e-03]
#  [-2.67738618e-03 -1.68047951e-03 -2.27790146e-03 -2.26954766e-03
#   -2.88680195e-03 -2.16546481e-03 -2.28900625e-03 -1.43083744e-03
#   -2.62624356e-03 -1.32992245e-03]
#  [-3.74065663e-03 -2.88888889e-03 -3.56445771e-03 -3.55555556e-03
#   -3.86371729e-03 -3.80035667e-03 -1.49243351e-03 -3.15142625e-03
#   -3.43827455e-03 -2.17282955e-03]]
# The operation took 4584.439120054245 seconds to complete.
