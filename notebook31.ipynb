# %%
import numpy as np

import RBN_flip


K = 4
N= 8
N_agent = 8
N_environment = 10
r = 0.5
mutation_rate = 0.5
threshold = 0
d_r = 0.05
d_mutation = 0.05
num_T = 30
num_processes = 10
maxiter = 150
iteration_for_average = 30
#p = 0.5
iterations_convergence = 20
# Create an instance of the RBN class
network = RBN_flip.RBN(K,N,r)

# %% [markdown]
# Plotting the graph

# %%
network.plot_states()

# %% [markdown]
# Printing the attractors and their probability

# %%
RBN_flip.print_pmf(network, N)
# Out:
# p( 01101000 ) : 0.01171875
# p( 10100001 ) : 0.0234375
# p( 11101000 ) : 0.96484375
# Probability sum: 1.0

# %% [markdown]
# # Calculating Fisher Information
#
# The cells below show proof that the Fisher information is calculated appropriately

# %% [markdown]
# Showing that the average of pmfs converges when the number used for the average is higher

# %%
RBN_flip.convergence(num_T, N, network,r)

# %% [markdown]
# A bar plot, showing the probability of each state of the network for r = 0.1 and r = 0.5
# (far and close to the maximum of the Fisher information).
# Now sorted on probability

# %%
#RBN_flip.sorted_pmf_plot(network, r, num_T, d_r)

# %% [markdown]
# Calculating the Fisher information for multiple r values
# Also showing the value of the difference between pmfs for a d_r, as a check on whether the code behind the Fisher plot works.

# %%
RBN_flip.Fisher_plot(d_r, num_T, threshold, num_processes, network)
# Out:
# C:\Users\emiel\OneDrive\Bureaublad\Capstone_g\RBN_flip.py:262: RuntimeWarning: divide by zero encountered in log
#   log_pmf = np.where(pmf == 0, 0, np.log(pmf))
# C:\Users\emiel\OneDrive\Bureaublad\Capstone_g\RBN_flip.py:263: RuntimeWarning: divide by zero encountered in log
#   log_pmf_prev = np.where(pmf_prev == 0, 0, np.log(pmf_prev))

# %% [markdown]
# Showing how the Hellinger distance decreases over epochs for a certain mutation rate and different r

# %%
# import time

# start_time = time.time()

# change_array, zero_array, iteration_to_zero_array, rate_array, hellinger_distance_stack = RBN_flip.calculate_decrease_hellinger_distance_r(K, r, iterations_convergence, mutation_rate, N_agent, N_environment, d_mutation, maxiter, iteration_for_average, d_r, num_T, threshold,num_processes)

# r_values = np.linspace(0, 1, len(change_array))
# RBN_flip.plot_results_r(r_values, rate_array)
# end_time = time.time() # End time after the operation

# duration = end_time - start_time # Duration of operation

# print(f"The operation took {duration} seconds to complete.")

# %% [markdown]
# Showing how the Hellinger distance decreasesover epochs for a certain r and different mutation rates

# %%
# import time

# start_time = time.time()

# change_array, zero_array, iteration_to_zero_array, rate_array, hellinger_distance_stack = RBN_flip.calculate_decrease_hellinger_distance_mutation(K, r, mutation_rate, N_agent, N_environment, d_mutation, maxiter,
#                                                    iteration_for_average, d_r, num_T, threshold,
#                                                    num_processes)
# mutation_values = np.linspace(0, 1, len(change_array))
# RBN_flip.plot_results_mutation(mutation_values, rate_array)

# end_time = time.time() # End time after the operation

# duration = end_time - start_time # Duration of operation

# print(f"The operation took {duration} seconds to complete.")

# %% [markdown]
# Showing how the Hellinger distance decreasesover epochs for a certain mutation values and different r

# %%
import time
K = 4
N= 6
N_agent = 6
N_environment = 8
r = 0.5
mutation_rate = 0.5
threshold = 0
d_r = 0.1
d_mutation = 0.1
num_T = 20
num_processes = 10
maxiter = 300
iteration_for_average = 60
#p = 0.5
iterations_convergence = 30
# Create an instance of the RBN class
network = RBN_flip.RBN(K,N,r)



start_time = time.time()

RBN_flip.convergence_plots_r(K, r, iterations_convergence, mutation_rate, N_agent, N_environment,d_mutation, maxiter, iteration_for_average, d_r, num_T, threshold, num_processes)
end_time = time.time() # End time after the operation

duration = end_time - start_time # Duration of operation

print(f"The operation took {duration} seconds to complete.")
# Out:
# The operation took 2135.8866617679596 seconds to complete.

# %% [markdown]
# Showing how the Hellinger distance decreasesover epochs for a certain r and different mutation rates

# %%
# start_time = time.time()
# RBN_flip.convergence_plots_mutation(K, r, mutation_rate,N_agent, N_environment, d_mutation, maxiter, iteration_for_average, d_r, num_T, threshold, num_processes)
# end_time = time.time() # End time after the operation

# duration = end_time - start_time # Duration of operation

# print(f"The operation took {duration} seconds to complete.")

# %% [markdown]
# Showing how the Hellinger distance decreases over epochs for a certain mutation rate and different r

# %%
K = 4  #Connectivity
N = 6
N_agent = 6  # Number of nodes agent
N_environment = 8  # Number of nodes environment
r = 0.5  # the value of the flip probability
mutation_rate = 0.5  # the value of the mutation rate
threshold = 0  # threshold for when we say the Hellinger distance between an agent and a Environment is negligible
d_r = 0.1  # values of the change of r, used for analysis
d_mutation = 0.1  # values of the change of the mutation rate, used for analysis
num_T = 20  # the humber of pmfs that is used to create a pmf that is used to calculate the Fisher information
maxiter = 300  # maximum number of iterations in the mutation process
iteration_for_average = 40  #amount of iterations of initializations of agents and environments that is used for analysis.
iterations_convergence = 10  # Not used at the moment
num_processes = 10  # Not used at the moment
network = RBN_flip.RBN(K,N,r)


start_time = time.time()

r_and_mutation_stack = RBN_flip.calculate_decrease_Hellinger_per_r_and_mutation_rate(K, r,iterations_convergence, mutation_rate, N_agent,
                                                                                         N_environment, maxiter,
                                                                                         iteration_for_average, d_r,
                                                                                         d_mutation, num_T, threshold,
                                                                                         num_processes)
RBN_flip.heatmap_r_mutation(r_and_mutation_stack, d_mutation, d_r)

end_time = time.time() # End time after the operation

duration = end_time - start_time # Duration of operation

print(f"The operation took {duration} seconds to complete.")
# Out:
# [[0.00000000e+000 0.00000000e+000 0.00000000e+000 0.00000000e+000
#   0.00000000e+000 4.94065646e-324 0.00000000e+000 0.00000000e+000
#   0.00000000e+000 0.00000000e+000 0.00000000e+000]
#  [0.00000000e+000 0.00000000e+000 0.00000000e+000 0.00000000e+000
#   0.00000000e+000 0.00000000e+000 6.95263915e-310 0.00000000e+000
#   0.00000000e+000 0.00000000e+000 0.00000000e+000]
#  [0.00000000e+000 1.42173718e-312 0.00000000e+000 0.00000000e+000
#   0.00000000e+000 0.00000000e+000 0.00000000e+000 0.00000000e+000
#   0.00000000e+000 0.00000000e+000 0.00000000e+000]
#  [0.00000000e+000 0.00000000e+000 0.00000000e+000 0.00000000e+000
#   0.00000000e+000 0.00000000e+000 0.00000000e+000 0.00000000e+000
#   0.00000000e+000 0.00000000e+000 0.00000000e+000]
#  [0.00000000e+000 0.00000000e+000 0.00000000e+000 0.00000000e+000
#   0.00000000e+000 0.00000000e+000 0.00000000e+000 0.00000000e+000
#   0.00000000e+000 0.00000000e+000 0.00000000e+000]
#  [0.00000000e+000 2.16939877e-317 0.00000000e+000 0.00000000e+000
#   0.00000000e+000 0.00000000e+000 0.00000000e+000 0.00000000e+000
#   0.00000000e+000 0.00000000e+000 0.00000000e+000]
#  [0.00000000e+000 0.00000000e+000 0.00000000e+000 0.00000000e+000
#   0.00000000e+000 0.00000000e+000 0.00000000e+000 0.00000000e+000
#   0.00000000e+000 0.00000000e+000 0.00000000e+000]
#  [0.00000000e+000 0.00000000e+000 0.00000000e+000 0.00000000e+000
#   0.00000000e+000 0.00000000e+000 0.00000000e+000 0.00000000e+000
#   0.00000000e+000 0.00000000e+000 0.00000000e+000]
#  [0.00000000e+000 0.00000000e+000 0.00000000e+000 0.00000000e+000
#   0.00000000e+000 0.00000000e+000 0.00000000e+000 0.00000000e+000
#   0.00000000e+000 0.00000000e+000 0.00000000e+000]
#  [0.00000000e+000 0.00000000e+000 0.00000000e+000 0.00000000e+000
#   0.00000000e+000 0.00000000e+000 0.00000000e+000 0.00000000e+000
#   0.00000000e+000 0.00000000e+000 0.00000000e+000]
#  [0.00000000e+000 0.00000000e+000 0.00000000e+000 0.00000000e+000
#   0.00000000e+000 0.00000000e+000 0.00000000e+000 4.94065646e-324
#   0.00000000e+000 0.00000000e+000 0.00000000e+000]]
# [[ 0.00000000e+000 -8.33333333e-005  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  4.94065646e-324  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -8.33333333e-005  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  6.95263915e-310  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -8.33333333e-005  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -8.33333333e-005  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -8.33333333e-005  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -3.50443385e-006  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -4.69498653e-007  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -8.33333333e-005  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000  4.94065646e-324
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]]
# [[ 0.00000000e+000 -8.33333333e-005 -1.66666667e-004  0.00000000e+000
#    0.00000000e+000  4.94065646e-324  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -8.33333333e-005  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  6.95263915e-310  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -8.33333333e-005  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -8.33333333e-005 -9.10569550e-005  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -8.33333333e-005 -1.11013783e-004  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -3.50443385e-006 -1.83717737e-005  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -4.69498653e-007 -1.87764862e-004  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000  0.00000000e+000 -8.81114755e-007  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000  0.00000000e+000 -2.51390186e-004  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000  0.00000000e+000 -8.33333333e-005  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -8.33333333e-005 -9.29040195e-005  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000  4.94065646e-324
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]]
# [[ 0.00000000e+000 -8.33333333e-005 -1.66666667e-004 -8.33333333e-005
#    0.00000000e+000  4.94065646e-324  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -8.33333333e-005  0.00000000e+000 -5.00000000e-004
#    0.00000000e+000  0.00000000e+000  6.95263915e-310  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -8.33333333e-005  0.00000000e+000 -5.13893659e-004
#    0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -8.33333333e-005 -9.10569550e-005 -2.36224271e-004
#    0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -8.33333333e-005 -1.11013783e-004 -1.43441932e-004
#    0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -3.50443385e-006 -1.83717737e-005 -1.37588303e-004
#    0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -4.69498653e-007 -1.87764862e-004 -2.70429832e-004
#    0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000  0.00000000e+000 -8.81114755e-007 -9.46570011e-005
#    0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000  0.00000000e+000 -2.51390186e-004 -4.10874852e-005
#    0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000  0.00000000e+000 -8.33333333e-005 -8.33333333e-005
#    0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -8.33333333e-005 -9.29040195e-005 -8.33333333e-005
#    0.00000000e+000  0.00000000e+000  0.00000000e+000  4.94065646e-324
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]]
# [[ 0.00000000e+000 -8.33333333e-005 -1.66666667e-004 -8.33333333e-005
#   -8.33333333e-005  4.94065646e-324  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -8.33333333e-005  0.00000000e+000 -5.00000000e-004
#   -3.37808677e-004  0.00000000e+000  6.95263915e-310  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -8.33333333e-005  0.00000000e+000 -5.13893659e-004
#   -1.57814922e-004  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -8.33333333e-005 -9.10569550e-005 -2.36224271e-004
#   -2.58773365e-004  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -8.33333333e-005 -1.11013783e-004 -1.43441932e-004
#   -1.08148798e-004  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -3.50443385e-006 -1.83717737e-005 -1.37588303e-004
#   -3.56498615e-004  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -4.69498653e-007 -1.87764862e-004 -2.70429832e-004
#   -2.71941334e-004  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000  0.00000000e+000 -8.81114755e-007 -9.46570011e-005
#   -4.78983880e-004  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000  0.00000000e+000 -2.51390186e-004 -4.10874852e-005
#   -2.63815885e-004  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000  0.00000000e+000 -8.33333333e-005 -8.33333333e-005
#   -2.50000000e-004  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -8.33333333e-005 -9.29040195e-005 -8.33333333e-005
#    0.00000000e+000  0.00000000e+000  0.00000000e+000  4.94065646e-324
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]]
# [[ 0.00000000e+000 -8.33333333e-005 -1.66666667e-004 -8.33333333e-005
#   -8.33333333e-005 -1.66666667e-004  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -8.33333333e-005  0.00000000e+000 -5.00000000e-004
#   -3.37808677e-004 -2.08024648e-004  6.95263915e-310  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -8.33333333e-005  0.00000000e+000 -5.13893659e-004
#   -1.57814922e-004 -4.94617862e-004  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -8.33333333e-005 -9.10569550e-005 -2.36224271e-004
#   -2.58773365e-004 -4.21028917e-004  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -8.33333333e-005 -1.11013783e-004 -1.43441932e-004
#   -1.08148798e-004 -4.37321513e-004  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -3.50443385e-006 -1.83717737e-005 -1.37588303e-004
#   -3.56498615e-004 -1.83352041e-004  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -4.69498653e-007 -1.87764862e-004 -2.70429832e-004
#   -2.71941334e-004 -3.36004016e-004  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000  0.00000000e+000 -8.81114755e-007 -9.46570011e-005
#   -4.78983880e-004 -3.47316334e-004  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000  0.00000000e+000 -2.51390186e-004 -4.10874852e-005
#   -2.63815885e-004 -2.73611138e-004  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000  0.00000000e+000 -8.33333333e-005 -8.33333333e-005
#   -2.50000000e-004 -4.26816883e-004  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -8.33333333e-005 -9.29040195e-005 -8.33333333e-005
#    0.00000000e+000 -2.50000000e-004  0.00000000e+000  4.94065646e-324
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]]
# [[ 0.00000000e+000 -8.33333333e-005 -1.66666667e-004 -8.33333333e-005
#   -8.33333333e-005 -1.66666667e-004 -1.66666667e-004  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -8.33333333e-005  0.00000000e+000 -5.00000000e-004
#   -3.37808677e-004 -2.08024648e-004 -4.66556413e-004  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -8.33333333e-005  0.00000000e+000 -5.13893659e-004
#   -1.57814922e-004 -4.94617862e-004 -4.27452080e-004  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -8.33333333e-005 -9.10569550e-005 -2.36224271e-004
#   -2.58773365e-004 -4.21028917e-004 -5.38381830e-004  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -8.33333333e-005 -1.11013783e-004 -1.43441932e-004
#   -1.08148798e-004 -4.37321513e-004 -3.90524689e-004  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -3.50443385e-006 -1.83717737e-005 -1.37588303e-004
#   -3.56498615e-004 -1.83352041e-004 -6.15242236e-004  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -4.69498653e-007 -1.87764862e-004 -2.70429832e-004
#   -2.71941334e-004 -3.36004016e-004 -4.92042091e-004  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000  0.00000000e+000 -8.81114755e-007 -9.46570011e-005
#   -4.78983880e-004 -3.47316334e-004 -4.17847149e-004  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000  0.00000000e+000 -2.51390186e-004 -4.10874852e-005
#   -2.63815885e-004 -2.73611138e-004 -4.25729253e-004  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000  0.00000000e+000 -8.33333333e-005 -8.33333333e-005
#   -2.50000000e-004 -4.26816883e-004 -4.27058508e-004  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -8.33333333e-005 -9.29040195e-005 -8.33333333e-005
#    0.00000000e+000 -2.50000000e-004 -2.31347173e-004  4.94065646e-324
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]]
# [[ 0.00000000e+00 -8.33333333e-05 -1.66666667e-04 -8.33333333e-05
#   -8.33333333e-05 -1.66666667e-04 -1.66666667e-04 -1.66666667e-04
#    0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00 -8.33333333e-05  0.00000000e+00 -5.00000000e-04
#   -3.37808677e-04 -2.08024648e-04 -4.66556413e-04 -5.01193589e-04
#    0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00 -8.33333333e-05  0.00000000e+00 -5.13893659e-04
#   -1.57814922e-04 -4.94617862e-04 -4.27452080e-04 -6.22366586e-04
#    0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00 -8.33333333e-05 -9.10569550e-05 -2.36224271e-04
#   -2.58773365e-04 -4.21028917e-04 -5.38381830e-04 -4.90738363e-04
#    0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00 -8.33333333e-05 -1.11013783e-04 -1.43441932e-04
#   -1.08148798e-04 -4.37321513e-04 -3.90524689e-04 -7.29213044e-04
#    0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00 -3.50443385e-06 -1.83717737e-05 -1.37588303e-04
#   -3.56498615e-04 -1.83352041e-04 -6.15242236e-04 -7.33354359e-04
#    0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00 -4.69498653e-07 -1.87764862e-04 -2.70429832e-04
#   -2.71941334e-04 -3.36004016e-04 -4.92042091e-04 -7.68978775e-04
#    0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00 -8.81114755e-07 -9.46570011e-05
#   -4.78983880e-04 -3.47316334e-04 -4.17847149e-04 -3.54639205e-04
#    0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00 -2.51390186e-04 -4.10874852e-05
#   -2.63815885e-04 -2.73611138e-04 -4.25729253e-04 -6.69964840e-04
#    0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00 -8.33333333e-05 -8.33333333e-05
#   -2.50000000e-04 -4.26816883e-04 -4.27058508e-04 -2.55382138e-04
#    0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00 -8.33333333e-05 -9.29040195e-05 -8.33333333e-05
#    0.00000000e+00 -2.50000000e-04 -2.31347173e-04 -1.66666667e-04
#    0.00000000e+00  0.00000000e+00  0.00000000e+00]]
# [[ 0.00000000e+00 -8.33333333e-05 -1.66666667e-04 -8.33333333e-05
#   -8.33333333e-05 -1.66666667e-04 -1.66666667e-04 -1.66666667e-04
#   -1.66666667e-04  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00 -8.33333333e-05  0.00000000e+00 -5.00000000e-04
#   -3.37808677e-04 -2.08024648e-04 -4.66556413e-04 -5.01193589e-04
#   -5.30373384e-04  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00 -8.33333333e-05  0.00000000e+00 -5.13893659e-04
#   -1.57814922e-04 -4.94617862e-04 -4.27452080e-04 -6.22366586e-04
#   -5.27862590e-04  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00 -8.33333333e-05 -9.10569550e-05 -2.36224271e-04
#   -2.58773365e-04 -4.21028917e-04 -5.38381830e-04 -4.90738363e-04
#   -5.49978207e-04  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00 -8.33333333e-05 -1.11013783e-04 -1.43441932e-04
#   -1.08148798e-04 -4.37321513e-04 -3.90524689e-04 -7.29213044e-04
#   -4.40107936e-04  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00 -3.50443385e-06 -1.83717737e-05 -1.37588303e-04
#   -3.56498615e-04 -1.83352041e-04 -6.15242236e-04 -7.33354359e-04
#   -6.19490876e-04  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00 -4.69498653e-07 -1.87764862e-04 -2.70429832e-04
#   -2.71941334e-04 -3.36004016e-04 -4.92042091e-04 -7.68978775e-04
#   -4.59639571e-04  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00 -8.81114755e-07 -9.46570011e-05
#   -4.78983880e-04 -3.47316334e-04 -4.17847149e-04 -3.54639205e-04
#   -3.98908508e-04  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00 -2.51390186e-04 -4.10874852e-05
#   -2.63815885e-04 -2.73611138e-04 -4.25729253e-04 -6.69964840e-04
#   -1.08572174e-03  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00 -8.33333333e-05 -8.33333333e-05
#   -2.50000000e-04 -4.26816883e-04 -4.27058508e-04 -2.55382138e-04
#   -3.36721902e-04  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00 -8.33333333e-05 -9.29040195e-05 -8.33333333e-05
#    0.00000000e+00 -2.50000000e-04 -2.31347173e-04 -1.66666667e-04
#   -1.76466152e-04  0.00000000e+00  0.00000000e+00]]
# [[ 0.00000000e+00 -8.33333333e-05 -1.66666667e-04 -8.33333333e-05
#   -8.33333333e-05 -1.66666667e-04 -1.66666667e-04 -1.66666667e-04
#   -1.66666667e-04 -2.50000000e-04  0.00000000e+00]
#  [ 0.00000000e+00 -8.33333333e-05  0.00000000e+00 -5.00000000e-04
#   -3.37808677e-04 -2.08024648e-04 -4.66556413e-04 -5.01193589e-04
#   -5.30373384e-04 -5.00604343e-04  0.00000000e+00]
#  [ 0.00000000e+00 -8.33333333e-05  0.00000000e+00 -5.13893659e-04
#   -1.57814922e-04 -4.94617862e-04 -4.27452080e-04 -6.22366586e-04
#   -5.27862590e-04 -7.16122958e-04  0.00000000e+00]
#  [ 0.00000000e+00 -8.33333333e-05 -9.10569550e-05 -2.36224271e-04
#   -2.58773365e-04 -4.21028917e-04 -5.38381830e-04 -4.90738363e-04
#   -5.49978207e-04 -3.88003865e-04  0.00000000e+00]
#  [ 0.00000000e+00 -8.33333333e-05 -1.11013783e-04 -1.43441932e-04
#   -1.08148798e-04 -4.37321513e-04 -3.90524689e-04 -7.29213044e-04
#   -4.40107936e-04 -5.17625012e-04  0.00000000e+00]
#  [ 0.00000000e+00 -3.50443385e-06 -1.83717737e-05 -1.37588303e-04
#   -3.56498615e-04 -1.83352041e-04 -6.15242236e-04 -7.33354359e-04
#   -6.19490876e-04 -7.08472890e-04  0.00000000e+00]
#  [ 0.00000000e+00 -4.69498653e-07 -1.87764862e-04 -2.70429832e-04
#   -2.71941334e-04 -3.36004016e-04 -4.92042091e-04 -7.68978775e-04
#   -4.59639571e-04 -7.38453982e-04  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00 -8.81114755e-07 -9.46570011e-05
#   -4.78983880e-04 -3.47316334e-04 -4.17847149e-04 -3.54639205e-04
#   -3.98908508e-04 -4.20727001e-04  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00 -2.51390186e-04 -4.10874852e-05
#   -2.63815885e-04 -2.73611138e-04 -4.25729253e-04 -6.69964840e-04
#   -1.08572174e-03 -6.10485263e-04  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00 -8.33333333e-05 -8.33333333e-05
#   -2.50000000e-04 -4.26816883e-04 -4.27058508e-04 -2.55382138e-04
#   -3.36721902e-04 -2.68483949e-04  0.00000000e+00]
#  [ 0.00000000e+00 -8.33333333e-05 -9.29040195e-05 -8.33333333e-05
#    0.00000000e+00 -2.50000000e-04 -2.31347173e-04 -1.66666667e-04
#   -1.76466152e-04 -1.03957997e-04  0.00000000e+00]]
# [[ 0.00000000e+00 -8.33333333e-05 -1.66666667e-04 -8.33333333e-05
#   -8.33333333e-05 -1.66666667e-04 -1.66666667e-04 -1.66666667e-04
#   -1.66666667e-04 -2.50000000e-04 -3.00576265e-04]
#  [ 0.00000000e+00 -8.33333333e-05  0.00000000e+00 -5.00000000e-04
#   -3.37808677e-04 -2.08024648e-04 -4.66556413e-04 -5.01193589e-04
#   -5.30373384e-04 -5.00604343e-04 -5.91788666e-04]
#  [ 0.00000000e+00 -8.33333333e-05  0.00000000e+00 -5.13893659e-04
#   -1.57814922e-04 -4.94617862e-04 -4.27452080e-04 -6.22366586e-04
#   -5.27862590e-04 -7.16122958e-04 -2.45710321e-04]
#  [ 0.00000000e+00 -8.33333333e-05 -9.10569550e-05 -2.36224271e-04
#   -2.58773365e-04 -4.21028917e-04 -5.38381830e-04 -4.90738363e-04
#   -5.49978207e-04 -3.88003865e-04 -8.48828296e-04]
#  [ 0.00000000e+00 -8.33333333e-05 -1.11013783e-04 -1.43441932e-04
#   -1.08148798e-04 -4.37321513e-04 -3.90524689e-04 -7.29213044e-04
#   -4.40107936e-04 -5.17625012e-04 -3.80232007e-04]
#  [ 0.00000000e+00 -3.50443385e-06 -1.83717737e-05 -1.37588303e-04
#   -3.56498615e-04 -1.83352041e-04 -6.15242236e-04 -7.33354359e-04
#   -6.19490876e-04 -7.08472890e-04 -5.11722496e-04]
#  [ 0.00000000e+00 -4.69498653e-07 -1.87764862e-04 -2.70429832e-04
#   -2.71941334e-04 -3.36004016e-04 -4.92042091e-04 -7.68978775e-04
#   -4.59639571e-04 -7.38453982e-04 -4.91470124e-04]
#  [ 0.00000000e+00  0.00000000e+00 -8.81114755e-07 -9.46570011e-05
#   -4.78983880e-04 -3.47316334e-04 -4.17847149e-04 -3.54639205e-04
#   -3.98908508e-04 -4.20727001e-04 -5.61131566e-04]
#  [ 0.00000000e+00  0.00000000e+00 -2.51390186e-04 -4.10874852e-05
#   -2.63815885e-04 -2.73611138e-04 -4.25729253e-04 -6.69964840e-04
#   -1.08572174e-03 -6.10485263e-04 -7.29960507e-04]
#  [ 0.00000000e+00  0.00000000e+00 -8.33333333e-05 -8.33333333e-05
#   -2.50000000e-04 -4.26816883e-04 -4.27058508e-04 -2.55382138e-04
#   -3.36721902e-04 -2.68483949e-04 -2.84208188e-04]
#  [ 0.00000000e+00 -8.33333333e-05 -9.29040195e-05 -8.33333333e-05
#    0.00000000e+00 -2.50000000e-04 -2.31347173e-04 -1.66666667e-04
#   -1.76466152e-04 -1.03957997e-04 -4.16666667e-04]]
# The operation took 16891.68091249466 seconds to complete.
