# %%
import numpy as np

import RBN_flip


K = 4
N= 8
N_agent = 8
N_environment = 10
r = 0.5
mutation_rate = 0.5
threshold = 0
d_r = 0.05
d_mutation = 0.05
num_T = 30
num_processes = 10
maxiter = 150
iteration_for_average = 30
#p = 0.5
iterations_convergence = 20
# Create an instance of the RBN class
network = RBN_flip.RBN(K,N,r)

# %% [markdown]
# Plotting the graph

# %%
network.plot_states()

# %% [markdown]
# Printing the attractors and their probability

# %%
RBN_flip.print_pmf(network, N)
# Out:
# p( 01010000 ) : 0.96875
# p( 01010111 ) : 0.03125
# Probability sum: 1.0

# %% [markdown]
# # Calculating Fisher Information
#
# The cells below show proof that the Fisher information is calculated appropriately

# %% [markdown]
# Showing that the average of pmfs converges when the number used for the average is higher

# %%
RBN_flip.convergence(num_T, N, network,r)

# %% [markdown]
# A bar plot, showing the probability of each state of the network for r = 0.1 and r = 0.5
# (far and close to the maximum of the Fisher information).
# Now sorted on probability

# %%
#RBN_flip.sorted_pmf_plot(network, r, num_T, d_r)

# %% [markdown]
# Calculating the Fisher information for multiple r values
# Also showing the value of the difference between pmfs for a d_r, as a check on whether the code behind the Fisher plot works.

# %%
RBN_flip.Fisher_plot(d_r, num_T, threshold, num_processes, network)

# %% [markdown]
# Showing how the Hellinger distance decreases over epochs for a certain mutation rate and different r

# %%
# import time

# start_time = time.time()

# change_array, zero_array, iteration_to_zero_array, rate_array, hellinger_distance_stack = RBN_flip.calculate_decrease_hellinger_distance_r(K, r, iterations_convergence, mutation_rate, N_agent, N_environment, d_mutation, maxiter, iteration_for_average, d_r, num_T, threshold,num_processes)

# r_values = np.linspace(0, 1, len(change_array))
# RBN_flip.plot_results_r(r_values, rate_array)
# end_time = time.time() # End time after the operation

# duration = end_time - start_time # Duration of operation

# print(f"The operation took {duration} seconds to complete.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10536\3723585955.py in <module>
#       3 start_time = time.time()
#       4
# ----> 5 change_array, zero_array, iteration_to_zero_array, rate_array, hellinger_distance_stack = RBN_flip.calculate_decrease_hellinger_distance_r(K, r, iterations_convergence, mutation_rate, N_agent, N_environment, d_mutation, maxiter, iteration_for_average, d_r, num_T, threshold,num_processes)
#       6
#       7 r_values = np.linspace(0, 1, len(change_array))
#
# ~\OneDrive\Bureaublad\Capstone_g\RBN_flip.py in calculate_decrease_hellinger_distance_r(K, r, iterations_convergence, mutation_rate, N_agent, N_environment, d_mutation, maxiter, iteration_for_average, d_r, num_T, threshold, num_processes)
#     821                                                                   num_processes)
#     822
# --> 823         average_count, av_it, av_rate_measure, steps_to_zero_array, av_distance = calculate_average_change(agent, pmf_environment,
#     824                                                                                               mutation_rate, maxiter,
#     825                                                                                               iteration_for_average)
#
# ~\OneDrive\Bureaublad\Capstone_g\RBN_flip.py in calculate_average_change(agent, pmf_environment, mutation_rate, maxiter, iteration_for_average)
#     681         # Run mutations over maxiter iterations
#     682         for j in range(maxiter):
# --> 683             agent, change_count, steps_to_zero, last_rate, iteration_to_zero, rate_measure, hellinger_distance_array, steps_to_zero_array = mutation(
#     684                 agent, pmf_environment, hellinger_distance_array, change_count, steps_to_zero, mutation_rate,
#     685                 start_for_rate, maxiter, j,
#
# ~\OneDrive\Bureaublad\Capstone_g\RBN_flip.py in mutation(agent, pmf_environment, hellinger_distance_array, change_count, steps_to_zero, mutation_rate, start_for_rate, maxiter, j, steps_to_zero_array)
#     627     initial_vector, sparse_matrix = agent.create_initial_vector_and_sparse_matrix()
#     628     pmf_agent_old = agent.find_stationary_distribution(initial_vector, sparse_matrix, tolerance=1e-8)
# --> 629     initial_vector, sparse_matrix = agent_new.create_initial_vector_and_sparse_matrix()
#     630     pmf_agent = agent_new.find_stationary_distribution(initial_vector, sparse_matrix, tolerance=1e-8)
#     631
#
# ~\OneDrive\Bureaublad\Capstone_g\RBN_flip.py in create_initial_vector_and_sparse_matrix(self)
#     283             for i in range(self.N):
#     284                 self.G.nodes[i]["state"] = Network_state[i]
# --> 285             self.step()
#     286             for i in range(self.N):
#     287                 after_step[i] = self.G.nodes[i]["state"]
#
# ~\OneDrive\Bureaublad\Capstone_g\RBN_flip.py in step(self, show_plot)
#     255             truth_table = self.G.nodes[node]["truth_table"]
#     256             input_vals = [self.G.nodes[input]["state"] for input in inputs]
# --> 257             index = self.bin_to_dec(input_vals)
#     258             output = truth_table[index]
#     259             new_state.append(output)
#
# ~\OneDrive\Bureaublad\Capstone_g\RBN_flip.py in bin_to_dec(self, bin_list)
#     233     # Helper functions to convert from binary to decimal and vice versa.
#     234     def bin_to_dec(self, bin_list):
# --> 235         return np.dot(bin_list, 2 ** np.arange(len(bin_list))[::-1])
#     236
#     237     def dec_to_bin(self, dec):
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# Showing how the Hellinger distance decreasesover epochs for a certain r and different mutation rates

# %%
# import time

# start_time = time.time()

# change_array, zero_array, iteration_to_zero_array, rate_array, hellinger_distance_stack = RBN_flip.calculate_decrease_hellinger_distance_mutation(K, r, mutation_rate, N_agent, N_environment, d_mutation, maxiter,
#                                                    iteration_for_average, d_r, num_T, threshold,
#                                                    num_processes)
# mutation_values = np.linspace(0, 1, len(change_array))
# RBN_flip.plot_results_mutation(mutation_values, rate_array)

# end_time = time.time() # End time after the operation

# duration = end_time - start_time # Duration of operation

# print(f"The operation took {duration} seconds to complete.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6164\527257385.py in <module>
#       3 start_time = time.time()
#       4
# ----> 5 change_array, zero_array, iteration_to_zero_array, rate_array, hellinger_distance_stack = RBN_flip.calculate_decrease_hellinger_distance_mutation(K, r, mutation_rate, N_agent, N_environment, d_mutation, maxiter,
#       6                                                    iteration_for_average, d_r, num_T, threshold,
#       7                                                    num_processes)
#
# ~\OneDrive\Bureaublad\Capstone_g\RBN_flip.py in calculate_decrease_hellinger_distance_mutation(K, r, mutation_rate, N_agent, N_environment, d_mutation, maxiter, iteration_for_average, d_r, num_T, threshold, num_processes)
#     735         pmf_environment, pmf_agent, agent = create_agent_and_environment(K, N_agent, N_environment, r, d_r, num_T, threshold,
#     736                                                                          num_processes)
# --> 737         average_count, av_it, av_rate_measure, steps_to_zero_array, av_distance = calculate_average_change(agent, pmf_environment,
#     738                                                                                               mutation_rate, maxiter,
#     739                                                                                               iteration_for_average)
#
# ~\OneDrive\Bureaublad\Capstone_g\RBN_flip.py in calculate_average_change(agent, pmf_environment, mutation_rate, maxiter, iteration_for_average)
#     681         # Run mutations over maxiter iterations
#     682         for j in range(maxiter):
# --> 683             agent, change_count, steps_to_zero, last_rate, iteration_to_zero, rate_measure, hellinger_distance_array, steps_to_zero_array = mutation(
#     684                 agent, pmf_environment, hellinger_distance_array, change_count, steps_to_zero, mutation_rate,
#     685                 start_for_rate, maxiter, j,
#
# ~\OneDrive\Bureaublad\Capstone_g\RBN_flip.py in mutation(agent, pmf_environment, hellinger_distance_array, change_count, steps_to_zero, mutation_rate, start_for_rate, maxiter, j, steps_to_zero_array)
#     627     initial_vector, sparse_matrix = agent.create_initial_vector_and_sparse_matrix()
#     628     pmf_agent_old = agent.find_stationary_distribution(initial_vector, sparse_matrix, tolerance=1e-8)
# --> 629     initial_vector, sparse_matrix = agent_new.create_initial_vector_and_sparse_matrix()
#     630     pmf_agent = agent_new.find_stationary_distribution(initial_vector, sparse_matrix, tolerance=1e-8)
#     631
#
# ~\OneDrive\Bureaublad\Capstone_g\RBN_flip.py in create_initial_vector_and_sparse_matrix(self)
#     287                 after_step[i] = self.G.nodes[i]["state"]
#     288
# --> 289             row_indices[k] = self.bin_to_dec(after_step)
#     290             col_indices[k] = k
#     291
#
# ~\OneDrive\Bureaublad\Capstone_g\RBN_flip.py in bin_to_dec(self, bin_list)
#     233     # Helper functions to convert from binary to decimal and vice versa.
#     234     def bin_to_dec(self, bin_list):
# --> 235         return np.dot(bin_list, 2 ** np.arange(len(bin_list))[::-1])
#     236
#     237     def dec_to_bin(self, dec):
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# Showing how the Hellinger distance decreasesover epochs for a certain mutation values and different r

# %%
import time
K = 4
N= 6
N_agent = 6
N_environment = 8
r = 0.5
mutation_rate = 0.5
threshold = 0
d_r = 0.1
d_mutation = 0.1
num_T = 20
num_processes = 10
maxiter = 300
iteration_for_average = 60
#p = 0.5
iterations_convergence = 30
# Create an instance of the RBN class
network = RBN_flip.RBN(K,N,r)



start_time = time.time()

RBN_flip.convergence_plots_r(K, r, iterations_convergence, mutation_rate, N_agent, N_environment,d_mutation, maxiter, iteration_for_average, d_r, num_T, threshold, num_processes)
end_time = time.time() # End time after the operation

duration = end_time - start_time # Duration of operation

print(f"The operation took {duration} seconds to complete.")
# Out:
# The operation took 1515.6636261940002 seconds to complete.

# %% [markdown]
# Showing how the Hellinger distance decreasesover epochs for a certain r and different mutation rates

# %%
# start_time = time.time()
# RBN_flip.convergence_plots_mutation(K, r, mutation_rate,N_agent, N_environment, d_mutation, maxiter, iteration_for_average, d_r, num_T, threshold, num_processes)
# end_time = time.time() # End time after the operation

# duration = end_time - start_time # Duration of operation

# print(f"The operation took {duration} seconds to complete.")
# Out:
# The operation took 1070.7882215976715 seconds to complete.

# %% [markdown]
# Showing how the Hellinger distance decreases over epochs for a certain mutation rate and different r

# %%
K = 4  #Connectivity
N = 6
N_agent = 6  # Number of nodes agent
N_environment = 8  # Number of nodes environment
r = 0.5  # the value of the flip probability
mutation_rate = 0.5  # the value of the mutation rate
threshold = 0  # threshold for when we say the Hellinger distance between an agent and a Environment is negligible
d_r = 0.1  # values of the change of r, used for analysis
d_mutation = 0.1  # values of the change of the mutation rate, used for analysis
num_T = 20  # the humber of pmfs that is used to create a pmf that is used to calculate the Fisher information
maxiter = 300  # maximum number of iterations in the mutation process
iteration_for_average = 40  #amount of iterations of initializations of agents and environments that is used for analysis.
iterations_convergence = 10  # Not used at the moment
num_processes = 10  # Not used at the moment
network = RBN_flip.RBN(K,N,r)


start_time = time.time()

r_and_mutation_stack = RBN_flip.calculate_decrease_Hellinger_per_r_and_mutation_rate(K, r,iterations_convergence, mutation_rate, N_agent,
                                                                                         N_environment, maxiter,
                                                                                         iteration_for_average, d_r,
                                                                                         d_mutation, num_T, threshold,
                                                                                         num_processes)
RBN_flip.heatmap_r_mutation(r_and_mutation_stack, d_mutation, d_r)

end_time = time.time() # End time after the operation

duration = end_time - start_time # Duration of operation

print(f"The operation took {duration} seconds to complete.")
# Out:
# [[0.00000000e+000 0.00000000e+000 0.00000000e+000 0.00000000e+000
#   0.00000000e+000 4.94065646e-324 0.00000000e+000 0.00000000e+000
#   0.00000000e+000 0.00000000e+000 0.00000000e+000]
#  [0.00000000e+000 0.00000000e+000 0.00000000e+000 0.00000000e+000
#   0.00000000e+000 0.00000000e+000 6.95263915e-310 0.00000000e+000
#   0.00000000e+000 0.00000000e+000 0.00000000e+000]
#  [0.00000000e+000 1.42173718e-312 0.00000000e+000 0.00000000e+000
#   0.00000000e+000 0.00000000e+000 0.00000000e+000 0.00000000e+000
#   0.00000000e+000 0.00000000e+000 0.00000000e+000]
#  [0.00000000e+000 0.00000000e+000 0.00000000e+000 0.00000000e+000
#   0.00000000e+000 0.00000000e+000 0.00000000e+000 0.00000000e+000
#   0.00000000e+000 0.00000000e+000 0.00000000e+000]
#  [0.00000000e+000 0.00000000e+000 0.00000000e+000 0.00000000e+000
#   0.00000000e+000 0.00000000e+000 0.00000000e+000 0.00000000e+000
#   0.00000000e+000 0.00000000e+000 0.00000000e+000]
#  [0.00000000e+000 2.16939877e-317 0.00000000e+000 0.00000000e+000
#   0.00000000e+000 0.00000000e+000 0.00000000e+000 0.00000000e+000
#   0.00000000e+000 0.00000000e+000 0.00000000e+000]
#  [0.00000000e+000 0.00000000e+000 0.00000000e+000 0.00000000e+000
#   0.00000000e+000 0.00000000e+000 0.00000000e+000 0.00000000e+000
#   0.00000000e+000 0.00000000e+000 0.00000000e+000]
#  [0.00000000e+000 0.00000000e+000 0.00000000e+000 0.00000000e+000
#   0.00000000e+000 0.00000000e+000 0.00000000e+000 0.00000000e+000
#   0.00000000e+000 0.00000000e+000 0.00000000e+000]
#  [0.00000000e+000 0.00000000e+000 0.00000000e+000 0.00000000e+000
#   0.00000000e+000 0.00000000e+000 0.00000000e+000 0.00000000e+000
#   0.00000000e+000 0.00000000e+000 0.00000000e+000]
#  [0.00000000e+000 0.00000000e+000 0.00000000e+000 0.00000000e+000
#   0.00000000e+000 0.00000000e+000 0.00000000e+000 0.00000000e+000
#   0.00000000e+000 0.00000000e+000 0.00000000e+000]
#  [0.00000000e+000 0.00000000e+000 0.00000000e+000 0.00000000e+000
#   0.00000000e+000 0.00000000e+000 0.00000000e+000 4.94065646e-324
#   0.00000000e+000 0.00000000e+000 0.00000000e+000]]
# [[ 0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  4.94065646e-324  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  6.95263915e-310  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -2.56310430e-006  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -9.13385539e-005  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -1.50334920e-004  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000  4.94065646e-324
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]]
# [[ 0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  4.94065646e-324  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  6.95263915e-310  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000  0.00000000e+000 -9.25185854e-021  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -2.56310430e-006 -6.91065445e-006  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -9.13385539e-005 -6.53604863e-007  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000 -1.50334920e-004 -1.84963742e-005  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000  0.00000000e+000 -8.31168578e-006  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000  0.00000000e+000  0.00000000e+000  0.00000000e+000
#    0.00000000e+000  0.00000000e+000  0.00000000e+000  4.94065646e-324
#    0.00000000e+000  0.00000000e+000  0.00000000e+000]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17988\2114347022.py in <module>
#      18 start_time = time.time()
#      19
# ---> 20 r_and_mutation_stack = RBN_flip.calculate_decrease_Hellinger_per_r_and_mutation_rate(K, r,iterations_convergence, mutation_rate, N_agent,
#      21                                                                                          N_environment, maxiter,
#      22                                                                                          iteration_for_average, d_r,
#
# ~\OneDrive\Bureaublad\Capstone_g\RBN_flip.py in calculate_decrease_Hellinger_per_r_and_mutation_rate(K, r, iterations_convergence, mutation_rate, N_agent, N_environment, maxiter, iteration_for_average, d_r, d_mutation, num_T, threshold, num_processes)
#     879     r = 0.5  # the value of the flip probability
#     880     mutation_rate = 0.5  # the value of the mutation rate
# --> 881     threshold = 0  # threshold for when we say the Hellinger distance between an agent and a Environment is negligible
#     882     d_r = 0.1  # values of the change of r, used for analysis
#     883     d_mutation = 0.1  # values of the change of the mutation rate, used for analysis
#
# ~\OneDrive\Bureaublad\Capstone_g\RBN_flip.py in calculate_decrease_hellinger_distance_r_multi_av(K, r, iterations_convergence, mutation_rate, N_agent, N_environment, d_mutation, maxiter, iteration_for_average, d_r, num_T, threshold, num_processes)
#     769                                                                   num_processes)
#     770
# --> 771         average_count, av_it, av_rate_measure, steps_to_zero_array, av_distance = calculate_average_change(agent, pmf_environment,
#     772                                                                                               mutation_rate, maxiter,
#     773                                                                                               iteration_for_average)
#
# ~\OneDrive\Bureaublad\Capstone_g\RBN_flip.py in calculate_average_change_multi_initial(K, N_agent, N_environment, r, d_r, num_T, threshold, num_processes, mutation_rate, maxiter, iteration_for_average)
#     719
#     720         iteration_to_zero_array[i] = av_it
# --> 721         if len(steps_to_zero_array) == 0:
#     722             zero_array[i] = 30
#     723         else:
#
# ~\OneDrive\Bureaublad\Capstone_g\RBN_flip.py in mutation(agent, pmf_environment, hellinger_distance_array, change_count, steps_to_zero, mutation_rate, start_for_rate, maxiter, j, steps_to_zero_array)
#     634                 steps_to_zero_array)
#     635         # Accumulate statistics
# --> 636         average_count += change_count
#     637         av_it += iteration_to_zero
#     638         av_rate_measure += rate_measure
#
# ~\OneDrive\Bureaublad\Capstone_g\RBN_flip.py in find_stationary_distribution(self, initial_vector, transition_matrix, tolerance, num_iterations)
#     307         # Process each pair of adjacent columns from the second column
#     308         for column_index in range(1, num_columns):
# --> 309             # Get the current and previous columns
#     310             column_1 = pmf_stack[:, column_index]
#     311             column_0 = pmf_stack[:, column_index - 1]
#
# <__array_function__ internals> in allclose(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\core\numeric.py in allclose(a, b, rtol, atol, equal_nan)
#    2247
#    2248     """
# -> 2249     res = all(isclose(a, b, rtol=rtol, atol=atol, equal_nan=equal_nan))
#    2250     return bool(res)
#    2251
#
# <__array_function__ internals> in isclose(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\core\numeric.py in isclose(a, b, rtol, atol, equal_nan)
#    2354
#    2355     xfin = isfinite(x)
# -> 2356     yfin = isfinite(y)
#    2357     if all(xfin) and all(yfin):
#    2358         return within_tol(x, y, atol, rtol)
#
# KeyboardInterrupt:
