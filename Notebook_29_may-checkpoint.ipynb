# %%
import RBN_flip

rbn = RBN_flip.RBN(2, 5, 0.5)
avg_pmf = RBN_flip.compute_average_pmf((rbn, 0.5, 10))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13776\3961996063.py in <module>
#       2
#       3 rbn = RBN_flip.RBN(2, 5, 0.5)
# ----> 4 avg_pmf = RBN_flip.compute_average_pmf((rbn, 0.5, 10))
#
# AttributeError: module 'RBN_flip' has no attribute 'compute_average_pmf'

# %%
from RBN_flip import RBN

K = 6
N = 8
r = 0.6

# Create an instance of the RBN class
network = RBN(K, N, r)

# Call methods on the RBN instance
network.plot_states()

# print_pmf function should be defined somewhere or imported if it is part of `RBN_flip_functions.py` file
print_pmf(network, N)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13776\72949507.py in <module>
#      12
#      13 # print_pmf function should be defined somewhere or imported if it is part of `RBN_flip_functions.py` file
# ---> 14 print_pmf(network, N)
#
# NameError: name 'print_pmf' is not defined

# %%
K = 6

N = 8
r = 0.6
threshold = 0
d_r = 0.05
num_T = 10
num_processes = 4

# Create an instance of the RBN class with 4 inputs per node, 10 nodes, and r=0.6
network = RBN(K, N, r)
# Create an instance of the RBN class with 4 inputs per node, 10 nodes, and r=0.6 K= 6
convergence(num_T, N, network, r)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13776\3888652648.py in <module>
#      11 network = RBN(K, N, r)
#      12 # Create an instance of the RBN class with 4 inputs per node, 10 nodes, and r=0.6 K= 6
# ---> 13 convergence(num_T, N, network, r)
#      14
#
# NameError: name 'convergence' is not defined

# %%
def main():   
    K = 6

    N = 5
    r = 0.6
    threshold = 0
    d_r = 0.05
    num_T = 10
    num_processes = 4

    # Create an instance of the RBN class with 4 inputs per node, 10 nodes, and r=0.6
    network = RBN(K, N, r)
    # Create an instance of the RBN class with 4 inputs per node, 10 nodes, and r=0.6 K= 6

    one_barplot(network, r, num_T, d_r)
    pmf_barplot(network, r, num_T, d_r)
    sorted_pmf_plot(network, r, num_T, d_r)
if __name__ == "__main__":
    main()

# %%
# Set parameters for the RBN
K = 4

N_agent = 3
N_environment = 4
r = 0.6
mutation_rate = 0.5
threshold = 0
d_r = 0.5
d_mutation = 0.5
num_T = 2
num_processes = 2
maxiter = 4
iteration_for_average = 2
#p = 0.5
iterations_convergence = 2



RBN_flip.convergence_plots_r(K, r, iterations_convergence, mutation_rate, N_agent, N_environment,d_mutation, maxiter, iteration_for_average, d_r, num_T, threshold, num_processes)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13776\3225592986.py in <module>
#      18
#      19
# ---> 20 RBN_flip.convergence_plots_r(K, r, iterations_convergence, mutation_rate, N_agent, N_environment,d_mutation, maxiter, iteration_for_average, d_r, num_T, threshold, num_processes)
#      21
#
# AttributeError: module 'RBN_flip' has no attribute 'convergence_plots_r'
