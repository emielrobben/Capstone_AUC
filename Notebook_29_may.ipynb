# %%
from RBN_flip import RBN  # assuming RBN is a class in RBN_flip_functions.py

K = 6
N = 8
r = 0.6

# Create an instance of the RBN class
network = RBN(K, N, r)

# Call methods on the RBN instance
network.plot_states()

# If print_pmf is a function in RBN_flip_functions.py, import and use it like this:
from RBN_flip import print_pmf

print_pmf(network, N)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1556\2865426325.py in <module>
#      12
#      13 # If print_pmf is a function in RBN_flip_functions.py, import and use it like this:
# ---> 14 from RBN_flip import print_pmf
#      15
#      16 print_pmf(network, N)
#
# ImportError: cannot import name 'print_pmf' from 'RBN_flip' (C:\Users\emiel\RBN_flip.py)

# %%
from RBN_flip_functions import RBN

K = 6
N = 8
r = 0.6

# Create an instance of the RBN class
network = RBN(K, N, r)

# Call methods on the RBN instance
network.plot_states()

# print_pmf function should be defined somewhere or imported if it is part of `RBN_flip_functions.py` file
print_pmf(network, N)

# %%
def main():   
    K = 6

    N = 8
    r = 0.6
    threshold = 0
    d_r = 0.05
    num_T = 10
    num_processes = 4

    # Create an instance of the RBN class with 4 inputs per node, 10 nodes, and r=0.6
    network = RBN(K, N, r)
    # Create an instance of the RBN class with 4 inputs per node, 10 nodes, and r=0.6 K= 6
    convergence(num_T, N, network, r)
if __name__ == "__main__":
    main()

# %%
def main():   
    K = 6

    N = 5
    r = 0.6
    threshold = 0
    d_r = 0.05
    num_T = 10
    num_processes = 4

    # Create an instance of the RBN class with 4 inputs per node, 10 nodes, and r=0.6
    network = RBN(K, N, r)
    # Create an instance of the RBN class with 4 inputs per node, 10 nodes, and r=0.6 K= 6

    one_barplot(network, r, num_T, d_r)
    pmf_barplot(network, r, num_T, d_r)
    sorted_pmf_plot(network, r, num_T, d_r)
if __name__ == "__main__":
    main()

# %%
def main():
    # Set parameters for the RBN
    K = 4

    N_agent = 3
    N_environment = 4
    r = 0.6
    mutation_rate = 0.5
    threshold = 0
    d_r = 0.5
    d_mutation = 0.5
    num_T = 2
    num_processes = 2
    maxiter = 4
    iteration_for_average = 2
    #p = 0.5
    iterations_convergence = 2


   
    convergence_plots_r(K, r, iterations_convergence, mutation_rate, N_agent, N_environment,d_mutation, maxiter, iteration_for_average, d_r, num_T, threshold, num_processes)


if __name__ == "__main__":
    main()
